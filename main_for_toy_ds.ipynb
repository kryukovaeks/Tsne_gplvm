# %% [markdown]
# # Twist

# %%
#you need to restart kernel for each cell
from GPLVM_twist_script import Twist_gplvm
Twist_gplvm(0.001,dim=2).plot_twist_project('twist.npy')

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from GPLVM_twist_script import Twist_gplvm
Twist_gplvm(0.01,dim=2).plot_twist_project('twist.npy')

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from GPLVM_twist_script import Twist_gplvm
Twist_gplvm(0.1,dim=2).plot_twist_project('twist.npy')

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from GPLVM_twist_script import Twist_gplvm
Twist_gplvm(1,dim=2).plot_twist_project('twist.npy')

# %%
# Twist to 1d

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from GPLVM_twist_script import Twist_gplvm
Twist_gplvm(0.1,dim=1).plot_twist_project('twist.npy')

# %% [markdown]
# # Twist with holes

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from GPLVM_twist_script import Twist_gplvm
Twist_gplvm(0.1,dim=2).plot_twist_project('twist_hole.npy')

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from GPLVM_twist_script import Twist_gplvm
Twist_gplvm(0.01,dim=2).plot_twist_project('twist_hole.npy')

# %% [markdown]
# # Twist with holes to 1d

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from GPLVM_twist_script import Twist_gplvm
Twist_gplvm(0.1,dim=1).plot_twist_project('twist_hole.npy')

# %% [markdown]
# # Cylinder

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from GPLVM_twist_script import Twist_gplvm
Twist_gplvm(0.1,dim=2).plot_twist_project('cylinder.npy')

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from GPLVM_twist_script import Twist_gplvm
Twist_gplvm(0.01,dim=2).plot_twist_project('cylinder.npy')

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from GPLVM_twist_script import Twist_gplvm
Twist_gplvm(0.001,dim=2).plot_twist_project('cylinder.npy')

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from GPLVM_twist_script import Twist_gplvm
Twist_gplvm(0.1,dim=1).plot_twist_project('cylinder.npy')

# %% [markdown]
# # Full cylinder

# %%
from GPLVM_twist_script import Twist_gplvm
Twist_gplvm(0.1,dim=2).plot_twist_project('cylinder_full.npy')

# %%
from IPython.display import display_html
def restartkernel() :
    display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
restartkernel()
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
from GPLVM_twist_script import Twist_gplvm
Twist_gplvm(0.1,dim=1).plot_twist_project('cylinder_full.npy')
